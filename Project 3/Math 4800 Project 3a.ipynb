# %% [markdown]
# Brian Holliday<br/>
# Professor Li<br/>
# Intro to Data Mining<br/>
# 19 February 2020

# %% [markdown]
# ## Project 3a

# %%
exams <- read.csv('exam_scores_all(1)(1).csv', sep = ',', na.strings = c('NO SCORE', 'withdraw','missed'), header = TRUE)

# %%
invisible(exams)

# %% [markdown]
# ### Problem 1

# %%
Final.Exam <- exams$Final.Exam

# %%
help(hist)

# %%
hist(Final.Exam[Final.Exam!=0], breaks = seq(0,100,by =10), 
                              col = 'blue', 
                              xlab = 'Final Exam Scores',
                            ylab = 'Frequency',
                             main = 'Final Exam Score Histogram')
# Out:
# Plot with title "Final Exam Score Histogram"

# %% [markdown]
# ### Problem 2

# %%
FE_hist <- hist(Final.Exam[Final.Exam!=0], breaks = seq(0,100,by =10),
                plot = FALSE)

# %%
counts_FE <- FE_hist$counts

# %%
breaks_FE <- FE_hist$breaks

# %%
exam1_hist <- hist(exams$Exam.1[exams$Exam.1!=0], breaks = seq(0,100,by =10),
                plot = FALSE)

# %%
counts1 <- exam1_hist$counts

# %%
breaks1 <- FE_hist$breaks

# %%
plot(c(5,breaks1 +5),c(0,counts1,0),pch = 19, 
     xlab = 'Exam 1 Scores',
    ylab = 'Frequency', main = 'Frequency Polygon',col = 'blue')
points(c(5,breaks_FE + 1), c(0,counts_FE,0), pch = 19, col = 'orange')
lines(c(5,breaks1 + 5),c(0,counts1,0))
lines(c(5,breaks_FE + 1), c(0,counts_FE,0))
# Out:
# Plot with title "Frequency Polygon"

# %%
help(points)
